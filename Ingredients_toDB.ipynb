# %%
import pandas as pd
import pymongo

# %%
ingredients_df = pd.read_excel('Resources/FinishedIngredients2.xlsx', index_col=None, header=None)
ingredients_df
# Out:
#                                            0
# 0                                     'salt'
# 1                             'kidney beans'
# 2                         'red wine vinegar'
# 3                             'cinnamon oil'
# 4                             'orange juice'
# ...                                      ...
# 14004                          'red bananas'
# 14005                     'broth seasonings'
# 14006   'spinach and artichoke cream cheese'
# 14007                       'preserved figs'
# 14008                  'red devil hot sauce'
#
# [14009 rows x 1 columns]

# %%
ingr_list = ingredients_df[0].tolist()

# %%
ingr_list
# Out:
# [" 'salt'",
#  " 'kidney beans'",
#  " 'red wine vinegar'",
#  " 'cinnamon oil'",
#  " 'orange juice'",
#  " 'cake flour'",
#  " 'walnuts'",
#  " 'garlic powder'",
#  " 'chicken rice soup'",
#  " 'hamburger buns'",
#  " 'fresh ground black pepper'",
#  " 'celery'",
#  " 'milk'",
#  " 'dried oregano'",
#  " 'baking powder'",
#  " 'tabasco sauce'",
#  " 'green beans'",
#  " 'condensed cream of mushroom soup'",
#  " 'sugar'",
#  " 'sage'",
#  " 'cooking oil'",
#  " 'toasted sesame seeds'",
#  " 'ground cinnamon'",
#  " 'water chestnut'",
#  " 'flat leaf parsley'",
#  " 'cheddar cheese'",
#  " 'eggs'",
#  " 'heavy cream'",
#  " 'vegetable oil'",
#  " 'tomato paste'",
#  " 'pepper'",
#  " 'ketchup'",
#  " 'dried basil'",
#  " 'cream'",
#  " 'onion'",
#  " 'bay leaf'",
#  " 'green olives'",
#  " 'prepared graham cracker crusts'",
#  " 'green pepper'",
#  " 'vanilla'",
#  " 'nuts'",
#  " 'sesame oil'",
#  " 'pecans'",
#  " 'olive oil'",
#  " 'parmesan cheese'",
#  " 'black pepper'",
# ...
